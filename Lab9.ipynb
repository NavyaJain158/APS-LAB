# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaJain158/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous_nodes = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous_nodes[neighbor] = min_node

    return distances, previous_nodes


def shortest_path(previous_nodes, start, target):
    path = []
    node = target
    while node is not None:
        path.insert(0, node)
        node = previous_nodes[node]
    return path

# %% [markdown]
# ### Demonstration with a Predefined Graph

# %%
def get_int_input(prompt):
    while True:
        try:
            value = int(input(prompt))
            return value
        except ValueError:
            print("Invalid input. Please enter a whole number.")

graph = {}
n = get_int_input("Enter number of nodes: ")

for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}
    m = get_int_input(f"Enter number of neighbors for {node}: ")
    for j in range(m):
        neighbor = input(f"  Neighbor {j+1} of {node}: ")
        weight = get_int_input(f"  Weight from {node} to {neighbor}: ")
        graph[node][neighbor] = weight

        if neighbor not in graph:
            graph[neighbor] = {}
while True:
    source = input("Enter source node: ")
    if source in graph:
        break
    else:
        print(f"Source node '{source}' not found in the graph. Please enter a valid node from {list(graph.keys())}.")

distances, previous_nodes = dijkstra(graph, source)
print(f"\nShortest paths from {source}:")
for node in graph:
    if distances[node] == float('inf'):
        print(f"Path to {node}: Unreachable, Distance = Unreachable")
    else:
        path = shortest_path(previous_nodes, source, node)
        print(f"Path to {node}: {' -> '.join(path)}, Distance = {distances[node]}")
# Out:
# Enter number of nodes: 3
# Enter node 1 name: a
# Enter number of neighbors for a: 1
#   Neighbor 1 of a: b
#   Weight from a to b: 2
# Enter node 2 name: c
# Enter number of neighbors for c: d
# Invalid input. Please enter a whole number.
# Enter number of neighbors for c: 1
#   Neighbor 1 of c: d
#   Weight from c to d: 5
# Enter node 3 name: g
# Enter number of neighbors for g: 2
#   Neighbor 1 of g: e
#   Weight from g to e: 4
#   Neighbor 2 of g: j
#   Weight from g to j: 7
# Enter source node: a
#
# Shortest paths from a:
# Path to a: a, Distance = 0
# Path to b: a -> b, Distance = 2
# Path to c: Unreachable, Distance = Unreachable
# Path to d: Unreachable, Distance = Unreachable
# Path to g: Unreachable, Distance = Unreachable
# Path to e: Unreachable, Distance = Unreachable
# Path to j: Unreachable, Distance = Unreachable

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
